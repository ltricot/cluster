# %%
from cluster import cluster

# %%
import numpy as np
import seaborn as sns

# %%
xs = [
    np.random.normal(loc=(i, j), scale=0.2, size=(1250, 2))
    for i in range(2)
    for j in range(2)
]

xs = np.vstack(xs)

# %%
ys, labels = cluster(xs, k=4)

# %%
sns.scatterplot(x=xs[:, 0], y=xs[:, 1], hue=labels)
# Out:
# <AxesSubplot: >

# %%
# %timeit cluster(xs, k=4)
# Out:
# 1.16 ms ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
